# %% [markdown]
# Clone

# %%
# %cd /root
# !git clone https://huggingface.co/spaces/victor/lance-zerogpu-demo
# %cd lance-zerogpu-demo
# Out:
# /root
# Cloning into 'lance-zerogpu-demo'...
# remote: Enumerating objects: 302, done.
# remote: Counting objects: 100% (298/298), done.
# remote: Compressing objects: 100% (290/290), done.
# remote: Total 302 (delta 138), reused 0 (delta 0), pack-reused 4 (from 1)
# Receiving objects: 100% (302/302), 627.58 KiB | 5.98 MiB/s, done.
# Resolving deltas: 100% (138/138), done.
# /root/lance-zerogpu-demo

# %% [markdown]
# Requirements

# %%
# !pip install -U pip setuptools wheel cython
# !pip install flash-attn==2.8.3 --no-build-isolation
# !pip install hf_transfer

# Core libs first (important order)
# !pip install numpy==1.26.4 scipy==1.12.0 PyYAML>=6.0.1

# Force PyTorch stack first if needed (optional but recommended)
# !pip install torch==2.4.1 torchvision==0.19.1 --index-url https://download.pytorch.org/whl/cu121

# Main requirements
# !pip install \
accelerate==1.13.0 \
addict==2.4.0 \
albumentations==1.4.3 \
Cython==3.0.11 \
decord==0.6.0 \
diffusers==0.29.1 \
einops==0.8.1 \
einops-exts==0.0.4 \
ftfy==6.1.1 \
h5py==3.12.1 \
"huggingface-hub>=0.34.0,<1.0" \
imageio==2.34.0 \
imageio-ffmpeg==0.5.1 \
kornia==0.8.2 \
librosa==0.10.2.post1 \
omegaconf==2.3.0 \
opencv-python-headless==4.9.0.80 \
peft==0.5.0 \
pillow==11.0.0 \
protobuf==3.20.3 \
psutil==5.9.4 \
scikit-image==0.24.0 \
sentencepiece==0.1.99 \
soundfile==0.12.1 \
tabulate==0.9.0 \
tenacity==8.2.2 \
termcolor==2.5.0 \
tiktoken==0.7.0 \
timm==0.6.13 \
torch-fidelity==0.3.0 \
torchlibrosa==0.1.0 \
torchmetrics==1.3.2 \
tqdm==4.67.3 \
transformers==4.49.0 \
transformers-stream-generator==0.0.5 \
webdataset==0.2.48 \
yacs==0.1.8 \
httpx==0.27.1 \
gpustat \
spaces==0.50.2 \
gradio==6.14.0 \
"uvicorn>=0.14.0" \
"websockets>=10.4"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 60.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 120.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 72.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.45.1
#     Uninstalling wheel-0.45.1:
#       Successfully uninstalled wheel-0.45.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 70.2.0
#     Uninstalling setuptools-70.2.0:
#       Successfully uninstalled setuptools-70.2.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.3.1
#     Uninstalling pip-24.3.1:
#       Successfully uninstalled pip-24.3.1
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 17.7 MB/s  0:00:00
# done
# ...
# done
#   Created wheel for flash-attn: filename=flash_attn-2.8.3-cp312-cp312-linux_x86_64.whl size=256040057 sha256=f25da18657a87fc83dc1bfb8b7751b82246e9db355510226b674fd437c34b5fb
# ...

# %% [markdown]
# Download Models

# %%
from huggingface_hub import snapshot_download

save_dir = "/root/lance-zerogpu-demo/downloads"
repo_id = "bytedance-research/Lance"

snapshot_download(
    repo_id=repo_id,
    local_dir=save_dir,
    local_dir_use_symlinks=False,
    resume_download=True,
    allow_patterns=[
        "Lance_3B/*",
        "Lance_3B_Video/*",
        "Qwen2.5-VL-ViT/*",
        "*.pth",
    ],
)
# Out:
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Lance_3B_Video/model.safetensors:   0%|          | 0.00/28.4G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/216 [00:00<?, ?B/s]
# llm_config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# '/root/lance-zerogpu-demo/downloads'

# %%
from huggingface_hub import hf_hub_download

hf_hub_download(
    repo_id="bytedance-research/Lance",
    filename="Wan2.2_VAE.pth",
    local_dir="/root/lance-zerogpu-demo/downloads"
)
# Out:
# Wan2.2_VAE.pth:   0%|          | 0.00/2.82G [00:00<?, ?B/s]
# '/root/lance-zerogpu-demo/downloads/Wan2.2_VAE.pth'

# %%
# !ls /root/lance-zerogpu-demo/downloads
# Out:
# Lance_3B  Lance_3B_Video  Qwen2.5-VL-ViT  Wan2.2_VAE.pth

# %% [markdown]
# Main Cell

# %%
# !python app.py --share
# Out:
# [lance-space] import: stdlib loaded
# [lance-space] import: loading gradio
# [lance-space] import: loading spaces
# [lance-space] import: loading torch
# [lance-space] import: loading safetensors/transformers
# [lance-space] import: loading Lance modules
# [lance-space] import: Lance modules loaded
# [lance-space] main: parsing args
# [lance-space] main: gpu_ids=0 queue=8
# [startup] Background model-file prefetch starting (startup): ['image']
# [lance-space] main: building demo
# [startup] image model files ready in 0.09s
# [startup] Background model-file prefetch finished.
# [lance-space] main: launching gradio
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://1749627dc69c117e49.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# ...
